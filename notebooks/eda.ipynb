# %%
import os
os.chdir('/mnt/c/projects/audio-classification')

# %%
import numpy as np
from src.format_data import MelspectrogramInput

# %%
audio = MelspectrogramInput('train_curated')

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(4, 8, figsize=(20,10))
for i, axi in enumerate(ax.flat):
    axi.imshow(audio.images[i], cmap='bone')
    axi.set(xticks=[], yticks=[],
            xlabel=audio.target_names[int(audio.target[i])])

# %%
unique, counts = np.unique(audio.target_names, return_counts=True)
dict(zip(unique, counts))
# Out:
# {'Accelerating_and_revving_and_vroom': 32,
#  'Accordion': 47,
#  'Acoustic_guitar': 3,
#  'Acoustic_guitar,Strum': 69,
#  'Applause,Cheering': 15,
#  'Applause,Cheering,Clapping': 5,
#  'Applause,Clapping': 3,
#  'Applause,Crowd': 10,
#  'Applause,Crowd,Cheering': 36,
#  'Applause,Crowd,Clapping': 1,
#  'Applause,Dishes_and_pots_and_pans,Crowd,Cheering,Clapping,Child_speech_and_kid_speaking': 1,
#  'Applause,Harmonica': 1,
#  'Applause,Harmonica,Cheering': 1,
#  'Applause,Screaming,Crowd': 2,
#  'Bark': 69,
#  'Bark,Chirp_and_tweet': 2,
#  'Bark,Cricket': 1,
#  'Bark,Cricket,Buzz': 1,
#  'Bark,Walk_and_footsteps': 2,
#  'Bass_drum': 68,
#  'Bass_guitar': 64,
#  'Bathtub_(filling_or_washing)': 56,
#  'Bathtub_(filling_or_washing),Child_speech_and_kid_speaking': 1,
#  'Bathtub_(filling_or_washing),Gurgling': 3,
#  'Bathtub_(filling_or_washing),Sink_(filling_or_washing)': 1,
#  'Bathtub_(filling_or_washing),Sink_(filling_or_washing),Water_tap_and_faucet': 1,
#  'Bathtub_(filling_or_washing),Water_tap_and_faucet': 5,
#  'Bicycle_bell': 67,
#  'Burping_and_eructation': 74,
#  'Burping_and_eructation,Chewing_and_mastication': 1,
#  'Bus': 70,
#  'Buzz': 52,
#  'Car_passing_by': 62,
#  'Car_passing_by,Accelerating_and_revving_and_vroom': 2,
#  'Car_passing_by,Race_car_and_auto_racing': 1,
#  'Car_passing_by,Traffic_noise_and_roadway_noise': 10,
#  'Cheering,Clapping': 6,
#  'Cheering,Yell': 1,
#  'Chewing_and_mastication': 74,
#  'Child_speech_and_kid_speaking': 72,
#  'Chink_and_clink': 38,
#  'Chirp_and_tweet': 66,
#  'Chirp_and_tweet,Buzz': 1,
#  'Chirp_and_tweet,Cricket': 1,
#  'Chirp_and_tweet,Slam': 1,
#  'Church_bell': 73,
#  'Church_bell,Traffic_noise_and_roadway_noise': 1,
#  'Clapping': 52,
#  'Clapping,Chirp_and_tweet': 1,
#  'Computer_keyboard': 75,
#  'Crackle': 73,
#  'Cricket': 68,
#  'Cricket,Buzz': 2,
#  'Cricket,Waves_and_surf': 2,
#  'Crowd': 5,
#  'Crowd,Bus': 1,
#  'Crowd,Cheering': 8,
#  'Crowd,Cheering,Yell': 1,
#  'Crowd,Clapping': 3,
#  'Crowd,Gasp': 2,
#  'Crowd,Race_car_and_auto_racing,Accelerating_and_revving_and_vroom': 2,
#  'Crowd,Yell': 1,
#  'Cupboard_open_or_close': 64,
#  'Cupboard_open_or_close,Drawer_open_or_close': 2,
#  'Cutlery_and_silverware': 33,
#  'Cutlery_and_silverware,Chink_and_clink': 1,
#  'Cutlery_and_silverware,Dishes_and_pots_and_pans': 29,
#  'Cutlery_and_silverware,Dishes_and_pots_and_pans,Chink_and_clink': 4,
#  'Cutlery_and_silverware,Drawer_open_or_close': 6,
#  'Cutlery_and_silverware,Sink_(filling_or_washing)': 1,
#  'Cutlery_and_silverware,Tap': 1,
#  'Dishes_and_pots_and_pans,Chink_and_clink': 27,
#  'Dishes_and_pots_and_pans,Cupboard_open_or_close': 1,
#  'Dishes_and_pots_and_pans,Hiss': 1,
#  'Dishes_and_pots_and_pans,Sink_(filling_or_washing)': 2,
#  'Drawer_open_or_close': 66,
#  'Drip': 4,
#  'Drip,Bathtub_(filling_or_washing)': 1,
#  'Drip,Gurgling': 1,
#  'Drip,Sink_(filling_or_washing)': 2,
#  'Drip,Sink_(filling_or_washing),Water_tap_and_faucet': 7,
#  'Drip,Trickle_and_dribble': 2,
#  'Drip,Water_tap_and_faucet': 3,
#  'Electric_guitar': 52,
#  'Electric_guitar,Acoustic_guitar': 1,
#  'Electric_guitar,Bass_drum': 1,
#  'Electric_guitar,Bass_guitar': 10,
#  'Electric_guitar,Bass_guitar,Hi-hat,Bass_drum': 1,
#  'Electric_guitar,Squeak': 4,
#  'Electric_guitar,Strum': 6,
#  'Fart': 74,
#  'Fart,Drawer_open_or_close': 1,
#  'Female_singing': 66,
#  'Female_singing,Male_singing': 9,
#  'Female_speech_and_woman_speaking': 44,
#  'Female_speech_and_woman_speaking,Walk_and_footsteps': 2,
#  'Female_speech_and_woman_speaking,Whispering': 4,
#  'Female_speech_and_woman_speaking,Yell': 22,
#  'Fill_(with_liquid)': 40,
#  'Fill_(with_liquid),Bathtub_(filling_or_washing)': 1,
#  'Fill_(with_liquid),Bathtub_(filling_or_washing),Water_tap_and_faucet': 1,
#  'Fill_(with_liquid),Sink_(filling_or_washing)': 3,
#  'Fill_(with_liquid),Sink_(filling_or_washing),Water_tap_and_faucet,Gurgling': 1,
#  'Fill_(with_liquid),Toilet_flush': 1,
#  'Fill_(with_liquid),Water_tap_and_faucet': 3,
#  'Finger_snapping': 75,
#  'Frying_(food)': 60,
#  'Frying_(food),Crackle': 2,
#  'Frying_(food),Dishes_and_pots_and_pans': 1,
#  'Gasp': 46,
#  'Glockenspiel': 56,
#  'Gong': 75,
#  'Gurgling': 52,
#  'Gurgling,Chink_and_clink': 1,
#  'Harmonica': 73,
#  'Hi-hat': 70,
#  'Hi-hat,Bass_drum': 4,
#  'Hiss': 72,
#  'Hiss,Bus': 1,
#  'Keys_jangling': 75,
#  'Knock': 70,
#  'Knock,Dishes_and_pots_and_pans': 1,
#  'Knock,Run': 1,
#  'Knock,Slam': 3,
#  'Male_singing': 65,
#  'Male_speech_and_man_speaking': 61,
#  'Male_speech_and_man_speaking,Female_speech_and_woman_speaking': 3,
#  'Male_speech_and_man_speaking,Male_singing': 1,
#  'Male_speech_and_man_speaking,Walk_and_footsteps': 2,
#  'Male_speech_and_man_speaking,Whispering': 2,
#  'Male_speech_and_man_speaking,Yell': 6,
#  'Marimba_and_xylophone': 75,
#  'Mechanical_fan': 49,
#  'Meow': 59,
#  'Meow,Bathtub_(filling_or_washing)': 1,
#  'Meow,Clapping': 1,
#  'Meow,Hiss': 1,
#  'Meow,Purr': 13,
#  'Microwave_oven': 68,
#  'Motorcycle': 59,
#  'Motorcycle,Accelerating_and_revving_and_vroom': 12,
#  'Motorcycle,Traffic_noise_and_roadway_noise': 4,
#  'Printer': 75,
#  'Purr': 52,
#  'Race_car_and_auto_racing': 27,
#  'Race_car_and_auto_racing,Accelerating_and_revving_and_vroom': 26,
#  'Raindrop': 19,
#  'Raindrop,Bathtub_(filling_or_washing)': 1,
#  'Raindrop,Drip': 52,
#  'Raindrop,Drip,Trickle_and_dribble': 1,
#  'Raindrop,Drip,Water_tap_and_faucet': 2,
#  'Run': 66,
#  'Run,Slam': 1,
#  'Scissors': 75,
#  'Screaming': 50,
#  'Screaming,Child_speech_and_kid_speaking': 1,
#  'Screaming,Crowd': 1,
#  'Screaming,Crowd,Cheering': 1,
#  'Screaming,Yell': 20,
#  'Shatter': 72,
#  'Shatter,Chink_and_clink': 3,
#  'Sigh': 57,
#  'Sink_(filling_or_washing),Gurgling': 4,
#  'Sink_(filling_or_washing),Water_tap_and_faucet': 46,
#  'Skateboard': 75,
#  'Slam': 39,
#  'Slam,Bus': 1,
#  'Slam,Microwave_oven': 7,
#  'Sneeze': 62,
#  'Sneeze,Church_bell': 1,
#  'Squeak': 22,
#  'Squeak,Accelerating_and_revving_and_vroom': 1,
#  'Squeak,Chirp_and_tweet': 1,
#  'Squeak,Clapping': 1,
#  'Squeak,Cupboard_open_or_close': 8,
#  'Squeak,Dishes_and_pots_and_pans': 1,
#  'Squeak,Dishes_and_pots_and_pans,Trickle_and_dribble': 1,
#  'Squeak,Slam': 21,
#  'Squeak,Walk_and_footsteps': 12,
#  'Squeak,Writing': 3,
#  'Stream': 71,
#  'Stream,Chirp_and_tweet': 1,
#  'Stream,Trickle_and_dribble': 1,
#  'Tap': 65,
#  'Tap,Acoustic_guitar': 1,
#  'Tap,Bass_drum': 1,
#  'Tap,Clapping': 1,
#  'Tap,Dishes_and_pots_and_pans': 5,
#  'Tap,Dishes_and_pots_and_pans,Chink_and_clink': 1,
#  'Tick-tock': 72,
#  'Toilet_flush': 63,
#  'Toilet_flush,Gurgling': 10,
#  'Toilet_flush,Water_tap_and_faucet': 1,
#  'Traffic_noise_and_roadway_noise': 57,
#  'Traffic_noise_and_roadway_noise,Bus': 2,
#  'Trickle_and_dribble': 35,
#  'Trickle_and_dribble,Bathtub_(filling_or_washing),Gurgling': 1,
#  'Trickle_and_dribble,Bathtub_(filling_or_washing),Sink_(filling_or_washing),Gurgling': 2,
#  'Trickle_and_dribble,Sink_(filling_or_washing)': 5,
#  'Trickle_and_dribble,Water_tap_and_faucet': 5,
#  'Walk_and_footsteps': 42,
#  'Walk_and_footsteps,Chirp_and_tweet': 1,
#  'Walk_and_footsteps,Run': 7,
#  'Walk_and_footsteps,Slam': 2,
#  'Walk_and_footsteps,Stream': 2,
#  'Walk_and_footsteps,Traffic_noise_and_roadway_noise': 1,
#  'Walk_and_footsteps,Waves_and_surf': 2,
#  'Waves_and_surf': 71,
#  'Whispering': 68,
#  'Whispering,Acoustic_guitar': 1,
#  'Writing': 72,
#  'Yell': 24,
#  'Zipper_(clothing)': 75}
